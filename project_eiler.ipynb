# %% [markdown]
# # Project Euler
#
# ## Этот документ создан для практики на сайте project-euler.net для решения задач

# %% [markdown]
# ### Первая задача
#
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get
# 3, 5, 6 and 9. The sum of these multiples is.
#
# Find the sum of all the multiples of 3 or 5 below 1000.

# %%
n = 1000
count = 0

for i in range(1, n):

    if i % 3 == 0 or i % 5 == 0:
        count += i

print(count)
# Out:
# 233168

# %% [markdown]
# ### Вторая задача
#
# Each new term in the Fibonacci sequence is generated by adding the previous two term.By starting with 1 and 2, the first 10 terms will be:
#
#                     1, 2, 3, 4, 5, 8, 13, 21, 34, 55, 89...
#
# By considering the terms in the Fibonacci sequence whose values do not exceed four million, find the sum of the even-valued terms.

# %%
cout1 = 1
cout2 = 2
sum = 2
i = 0

while i<4000000:

    i = cout1 + cout2
    cout1 = cout2
    cout2 = i
    if i % 2 == 0:
        sum += i   
        
print(sum)
# Out:
# 4613732
